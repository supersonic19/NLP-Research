# %%
from newsapi import NewsApiClient

# %%
newsapi = NewsApiClient(api_key='392dcc81fcdf4eb0a88823a7423fd3b5')

# %%
news = newsapi.get_everything(q='sexism' , 
                        language='en')

# %%
news
# Out:
# {'status': 'ok',
#  'totalResults': 1451,
#  'articles': [{'source': {'id': 'wired', 'name': 'Wired'},
#    'author': "Cecilia D'Anastasio",
#    'title': 'The Rot of Riot Games Culture Starts at the Top',
#    'description': 'CEO Nicolo Laurent continues to employ multiple top executives who have been accused of sexism and harassment—and is himself the subject of a complaint.',
#    'url': 'https://www.wired.com/story/riot-games-ceo-culture-complaints/',
#    'urlToImage': 'https://media.wired.com/photos/6026ccffb2bf13443c5eef24/191:100/w_1280,c_limit/games_riot_1186330951.jpg',
#    'publishedAt': '2021-02-12T23:04:22Z',
#    'content': 'In 2014, Riot Games then-executive assistant Melanie McCracken began to notice that her supervisor, Jin Oh, didnt seem to hire women into senior leadership vacancies. Women were generally brought on … [+4114 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': None,
# ...
